# %%
N = 10000
totient = [0] * (N+1)
sigma = [0] * (N+1)

with open("data.csv") as h:
    for line in h.read().split("\n"):
        a, b, c = map(int, line.split(" "))
        totient[a] = b
        sigma[a] = c
        if a == N: break

# %%
import math
c = 6**0.5 / math.pi

import numpy as np
import matplotlib.pyplot as plt

# %%
from collections import Counter

pfactorize = [Counter() for _ in range(N + 1)]

def init_pfactorize():
    for i in range(2, N + 1):
        if pfactorize[i]:
            continue
        
        pow_i = i
        while pow_i <= N:
            for j in range(pow_i, N + 1, pow_i):
                pfactorize[j][i] += 1
            if pow_i > N // i:
                break
            pow_i *= i

init_pfactorize()

# %%
GM = [(totient[i]*sigma[i])**0.5 for i in range(N+1)]

GM_norm = [0] + [GM[i]/i for i in range(1, N+1)]

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8), dpi=100)
x = np.arange(1, N+1)
plt.plot(x, GM_norm[1:N+1], ',', label='GM')

x_2p = np.array([i for i in range(1, N+1) if pfactorize[i][2] == 1 and len(list(pfactorize[i])) <= 2])
plt.plot(x_2p, [GM_norm[x] for x in x_2p], '_', label='GM')

# Customize the plot
plt.title('$f(n) = \dfrac{\sqrt{\phi(n)\cdot\sigma(n)}}{n}$')
plt.legend()
plt.grid(True, axis='y')
plt.show()

# %%
x_2p
# Out:
# array([   2,    6,   10,   14,   18,   22,   26,   34,   38,   46,   50,
#          54,   58,   62,   74,   82,   86,   94,   98,  106,  118,  122,
#         134,  142,  146,  158,  162,  166,  178,  194,  202,  206,  214,
#         218,  226,  242,  250,  254,  262,  274,  278,  298,  302,  314,
#         326,  334,  338,  346,  358,  362,  382,  386,  394,  398,  422,
#         446,  454,  458,  466,  478,  482,  486,  502,  514,  526,  538,
#         542,  554,  562,  566,  578,  586,  614,  622,  626,  634,  662,
#         674,  686,  694,  698,  706,  718,  722,  734,  746,  758,  766,
#         778,  794,  802,  818,  838,  842,  862,  866,  878,  886,  898,
#         914,  922,  926,  934,  958,  974,  982,  998, 1006, 1018, 1042,
#        1046, 1058, 1082, 1094, 1114, 1126, 1138, 1142, 1154, 1174, 1186,
#        1198, 1202, 1214, 1226, 1234, 1238, 1250, 1262, 1282, 1286, 1294,
#        1306, 1318, 1322, 1346, 1354, 1366, 1382, 1402, 1418, 1438, 1454,
#        1458, 1466, 1478, 1486, 1502, 1514, 1522, 1538, 1546, 1574, 1594,
#        1618, 1622, 1642, 1646, 1654, 1658, 1678, 1682, 1706, 1714, 1718,
#        1726, 1754, 1762, 1766, 1774, 1814, 1822, 1838, 1858, 1874, 1882,
#        1894, 1906, 1922, 1934, 1942, 1954, 1966, 1982, 1994, 2018, 2026,
#        2038, 2042, 2062, 2066, 2078, 2098, 2102, 2122, 2126, 2138, 2174,
#        2182, 2186, 2194, 2206, 2218, 2234, 2246, 2258, 2302, 2306, 2326,
#        2342, 2362, 2374, 2386, 2402, 2426, 2434, 2446, 2458, 2462, 2474,
#        2498, 2518, 2554, 2558, 2566, 2578, 2582, 2594, 2602, 2606, 2614,
#        2638, 2642, 2654, 2662, 2722, 2734, 2738, 2746, 2762, 2798, 2818,
#        2846, 2854, 2858, 2866, 2878, 2894, 2902, 2906, 2918, 2942, 2962,
#        2966, 2974, 2978, 2986, 2998, 3022, 3046, 3062, 3086, 3098, 3106,
#        3118, 3134, 3142, 3158, 3166, 3194, 3202, 3214, 3218, 3226, 3238,
#        3242, 3254, 3274, 3314, 3326, 3334, 3338, 3362, 3386, 3394, 3398,
