# %%
import math
import numpy as np
import matplotlib.pyplot as plt

N = 1000000
import funcs
funcs.init(N)
phi = [0]+[funcs.totient[i] for i in range(1, N+1)]
sigma = [0]+[funcs.sigma[i] for i in range(1, N+1)]
pfactorize=funcs.pfactorize
# Out:
# Initializing precomputed data up to n=1000000...
#
# Loading totient and sigma...		 finished (1167 ms)
# Computing prime factorizations...	 finished (4424 ms)
#
# Initialization completed in 5592 ms

# %%
s = 0
for i in range(1, 1000001):
    s+=i/phi[i]
    #print(f"{i}: {s}")
    if s>2*i:
        print(i, s)
